# %% [markdown]
# # Q1：條件式顏色折線圖
# 給定每日溫度資料, 請完成以下操作：
# 1. 畫折線圖 (`plt.plot`)
# 2. 當溫度 ≥ 28 時，折線顏色為紅色，其餘為藍色  (plt.scatter)
# 3. 加上標題 `"Weekly Temperature"`
# 4. x 軸標籤 `"Day"`，y 軸標籤 `"Temperature (°C)"`

# %%
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5, 6, 7]
temperature = [22, 25, 20, 27, 30, 28, 24]

# ------- your code -------------

# %% [markdown]
# ---
# # Q2 : 有兩組數據, 請完成：
# 1. 使用 `plt.subplots` 建立兩個子圖（左右排列）
# 2. 左圖畫 `sales_a` 的折線圖
# 3. 右圖畫 `sales_b` 的折線圖
# 4. 每個子圖加上對應標題 `"Product A"` / `"Product B"`

# %%
sales_a = [200, 250, 300, 280]
sales_b = [180, 230, 310, 260]
months = ['Jan', 'Feb', 'Mar', 'Apr']

# ------- your code -------------

# %% [markdown]
# ---
# # Q3 : 有一組學生成績資料, 請完成：
# 1. 畫直方圖（bins=5）
# 2. 計算平均分數並用紅色虛線標註在圖上
# 3. 在平均線上加文字 `"Mean"`
# 4. 加上標題 `"Score Distribution"`

# %%
import numpy as np

scores = [78, 85, 92, 67, 80, 73, 88, 95, 60, 82]

# ------- your code -------------

# %% [markdown]
# ---
# # Q4 : 美化圓餅圖與標籤提取 (Exploded Pie Chart)
#
# 假設你有一組手機品牌的市場份額數據。請畫出一張圓餅圖，並要求：
#
# 1. 將市場份額最大的品牌（Apple）**抽離 (Explode)** 出來以示強調。
# 2. 顯示百分比至小數點後第一位。
# 3. 加入陰影效果並自定義顏色組合（使用 `colors` 參數）。

# %%
import matplotlib.pyplot as plt

# 數據
labels = ['Apple', 'Samsung', 'Xiaomi', 'Oppo', 'Others']
sizes = [30, 25, 15, 10, 20]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99', '#c2c2f0']
explode = (0.1, 0, 0, 0, 0)  # 僅將第一個 (Apple) 抽離

# ------- your code -------------

# %% [markdown]
# ---
# # Q5：比較不同組別的數據分佈 (Overlaid Histograms)
# 假設你有兩組學生的考試分數數據，一組是**男生**，一組是**女生**。請用一張圖，使用**直方圖疊加 (Overlaid Histograms)** 的方式，比較兩組分數的分佈情況，並加入圖例。請將直方圖的透明度設為 0.5。

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. 產生模擬數據
np.random.seed(42)
male_scores = np.random.normal(loc=75, scale=10, size=100) # 男生分數，均值75，標準差10
female_scores = np.random.normal(loc=80, scale=8, size=120) # 女生分數，均值80，標準差8

# ------- your code -------------
